# %%
import os
import sys

import numpy as np
import pandas as pd
import seaborn as sns
import gseapy as gp

from lifelines import KaplanMeierFitter as KM
from lifelines import CoxPHFitter as cox
from matplotlib import pyplot as plt
from pandas import DataFrame as df
from scipy import stats
from IPython.display import Image

import matplotlib
import matplotlib.font_manager as fm
from matplotlib.ft2font import FT2Font
from matplotlib.colors import ListedColormap, LinearSegmentedColormap

def get_font(*args, **kwargs):
    return FT2Font(*args, **kwargs)

fm.get_font = get_font

matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# %%
import gc
gc.collect()
# Out:
# 422

# %% [markdown]
# # Global Path

# %%
poseidon_home = '/home/dyang-server/hdd/Yue/PROJECTS/POSEIDON/'
data_home = poseidon_home + 'data/'
gsea_home = poseidon_home + 'GSEA/'
cmap_home = data_home + 'CMAP2020_Cancer/'
shift_home = poseidon_home + 'shift_ability/'
panel_home = poseidon_home + 'panels/Figure3/'

# %%
gene_sets = {}
with open(gsea_home + '/gene_sets/NREC_REC_91061.gmt', 'r') as f:
    for lines in f:
        lines = lines.rstrip().split('\t')
        gene_sets[lines[0]] = lines[2:]

# %%
ec_color = df(index=gene_sets['NREC_profile'] + gene_sets['REC_profile'], columns=['colors'])
ec_color.loc[gene_sets['NREC_profile'], 'colors'] = 'crimson'
ec_color.loc[gene_sets['REC_profile'], 'colors'] = 'royalblue'

# %%
# L1000 gene info
bing_landmark = pd.read_csv(data_home + 'CMAP2020_Cancer/landmark_and_bings_L1000.csv',
                            header=0, index_col=0, sep=',', dtype={'Official NCBI gene symbol': 'str'}, converters={'Official NCBI gene symbol': None})
bing_landmark
# Out:
#                       Official NCBI gene symbol
# Official NCBI gene id
# 5720                                      PSME1
# 7416                                      VDAC1
# 55847                                     CISD1
# 10174                                    SORBS3
# 25803                                     SPDEF
# ...                                         ...
# 5137                                      PDE1C
# 51233                                    DRICH1
# 4340                                        MOG
# 1656                                       DDX6
# 23620                                     NTSR2
#
# [10174 rows x 1 columns]

# %%
sig_info = pd.read_csv(data_home + 'CMAP2020_Cancer/siginfo_beta.txt',
                            header=0, index_col='sig_id', sep='\t')
# Out:
# /home/dyang-server/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (0,3,4,28,29) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
sig_info = sig_info[sig_info['tas'] >= 0.4]

# %%
sig_info.columns
# Out:
# Index(['bead_batch', 'nearest_dose', 'pert_dose', 'pert_dose_unit',
#        'pert_idose', 'pert_itime', 'pert_time', 'pert_time_unit',
#        'cell_mfc_name', 'pert_mfc_id', 'nsample', 'cc_q75', 'ss_ngene', 'tas',
#        'pct_self_rank_q25', 'wt', 'median_recall_rank_spearman',
#        'median_recall_rank_wtcs_50', 'median_recall_score_spearman',
#        'median_recall_score_wtcs_50', 'batch_effect_tstat',
#        'batch_effect_tstat_pct', 'is_hiq', 'qc_pass', 'pert_id', 'pert_type',
#        'cell_iname', 'det_wells', 'det_plates', 'distil_ids', 'build_name',
#        'project_code', 'cmap_name', 'is_exemplar_sig', 'is_ncs_sig',
#        'is_null_sig'],
#       dtype='object')

# %%
compound_info = pd.read_csv(data_home + '/CMAP2020_Cancer/compoundinfo_beta.txt',
                            header=0, index_col=1, sep='\t')
compound_info = compound_info.groupby(level=0).first()
compound_info
# Out:
#                               pert_id  target  \
# cmap_name
# 1-EBIO                  BRD-K70586315     NaN
# 1-HYDROXYANTHRAQUINONE  BRD-K62620932     NaN
# 1-HYDROXYPHENAZINE      BRD-K66151076     NaN
# 1-NAPHTHYLAMINE         BRD-K05741221     NaN
# 1-NITRONAPHTHALENE      BRD-K72839221     NaN
# ...                               ...     ...
# zolpidem                BRD-K44876623  GABRA1
# zonisamide              BRD-A28095882  SCN11A
# zopiclone               BRD-A34309505  GABRA1
# zosuquidar              BRD-K70557564   ABCB1
# zoxazolamine            BRD-K66353228     NaN
#
#                                                     moa  \
# cmap_name
# 1-EBIO                                              NaN
# 1-HYDROXYANTHRAQUINONE                              NaN
# 1-HYDROXYPHENAZINE                                  NaN
# 1-NAPHTHYLAMINE                                     NaN
# 1-NITRONAPHTHALENE                                  NaN
# ...                                                 ...
# zolpidem                Benzodiazepine receptor agonist
# zonisamide                       Sodium channel blocker
# zopiclone                         GABA receptor agonist
# zosuquidar                     P-glycoprotein inhibitor
# zoxazolamine                                        NaN
#
#                                                          canonical_smiles  \
# cmap_name
# 1-EBIO                                               CCn1c2ccccc2[nH]c1=O
# 1-HYDROXYANTHRAQUINONE                                                NaN
# 1-HYDROXYPHENAZINE                                                    NaN
# 1-NAPHTHYLAMINE                                                       NaN
# 1-NITRONAPHTHALENE                                                    NaN
# ...                                                                   ...
# zolpidem                        CN(C)C(=O)Cc1c(nc2ccc(C)cn12)-c1ccc(C)cc1
# zonisamide                           CN1C2CCC1CC(C2)OC(c3ccccc3)c4ccccc4N
# zopiclone                CN1CCN(CC1)C(=O)OC2N(C(=O)c3nccnc23)c4ccc(Cl)cn4
# zosuquidar              O[C@@H](COc1cccc2ncccc12)CN1CCN(CC1)[C@@H]1c2c...
# zoxazolamine                                           Nc1nc2cc(Cl)ccc2o1
#
#                                           inchi_key compound_aliases
# cmap_name
# 1-EBIO                  CXUCKELNYMZTRT-UHFFFAOYSA-N              NaN
# 1-HYDROXYANTHRAQUINONE                          NaN              NaN
# 1-HYDROXYPHENAZINE                              NaN              NaN
# 1-NAPHTHYLAMINE                                 NaN              NaN
# 1-NITRONAPHTHALENE                              NaN              NaN
# ...                                             ...              ...
# zolpidem                ZAFYATHCZYHLPB-UHFFFAOYSA-N              NaN
# zonisamide              KZFDKINRISJFCO-UHFFFAOYSA-N              NaN
# zopiclone               GBBSUAFBMRNDJC-UHFFFAOYSA-N              NaN
# zosuquidar              IHOVFYSQUDPMCN-DBEBIPAYSA-N              NaN
# zoxazolamine            YGCODSQDUUUKIV-UHFFFAOYSA-N              NaN
#
# [33627 rows x 6 columns]

# %% [markdown]
# # Table of EC genes

# %%
ec_table = df(index=ec_color.index, columns=['EC_profile', 'total_shRNA_expr'])

# add the ec profile first
for g in ec_table.index:
    if g in gene_sets['NREC_profile']:
        ec_table.at[g, 'EC_profile'] = 'NR-EC'
    else:
        ec_table.at[g, 'EC_profile'] = 'R-EC'

# %%
sig_info_shRNA = sig_info[sig_info['pert_type'] == 'trt_sh']

# %%
sig_info_shRNA
# Out:
#                                       bead_batch  nearest_dose  pert_dose  \
# sig_id
# TAK003_PC3_96H:TRCN0000245327:-666            b7           NaN        NaN
# TAK001_HEKTE_96H:TRCN0000298904:-666          b7           NaN        NaN
# TAK003_HEKTE_96H:TRCN0000059068:-666          b7           NaN        NaN
# TAK001_SW480_96H:J10                          b6           NaN        NaN
# EKW001_PC3_120H:TRCN0000021242:2            f1b3           NaN        2.0
# ...                                          ...           ...        ...
# ERGK010_VCAP_120H:TRCN0000002000:-666         b2           NaN        NaN
# ERGK002_VCAP_120H:E03                         b2           NaN        NaN
# ERGK013_VCAP_120H:TRCN0000196700:-666         b3           NaN        NaN
# ERGK013_VCAP_120H:TRCN0000039901:-666         b3           NaN        NaN
# ERGK002_VCAP_120H:N01                         b2           NaN        NaN
#
#                                       pert_dose_unit pert_idose pert_itime  \
# sig_id
# TAK003_PC3_96H:TRCN0000245327:-666               NaN        NaN       96 h
# TAK001_HEKTE_96H:TRCN0000298904:-666             NaN        NaN       96 h
# TAK003_HEKTE_96H:TRCN0000059068:-666             NaN        NaN       96 h
# TAK001_SW480_96H:J10                             NaN        NaN       96 h
# EKW001_PC3_120H:TRCN0000021242:2                  uL       2 uL      120 h
# ...                                              ...        ...        ...
# ERGK010_VCAP_120H:TRCN0000002000:-666            NaN        NaN      120 h
# ERGK002_VCAP_120H:E03                            NaN        NaN      120 h
# ERGK013_VCAP_120H:TRCN0000196700:-666            NaN        NaN      120 h
# ERGK013_VCAP_120H:TRCN0000039901:-666            NaN        NaN      120 h
# ERGK002_VCAP_120H:N01                            NaN        NaN      120 h
#
#                                        pert_time pert_time_unit cell_mfc_name  \
# sig_id
# TAK003_PC3_96H:TRCN0000245327:-666          96.0              h           PC3
# TAK001_HEKTE_96H:TRCN0000298904:-666        96.0              h         HEKTE
# TAK003_HEKTE_96H:TRCN0000059068:-666        96.0              h         HEKTE
# TAK001_SW480_96H:J10                        96.0              h         SW480
# EKW001_PC3_120H:TRCN0000021242:2           120.0              h           PC3
# ...                                          ...            ...           ...
# ERGK010_VCAP_120H:TRCN0000002000:-666      120.0              h          VCAP
# ERGK002_VCAP_120H:E03                      120.0              h          VCAP
# ERGK013_VCAP_120H:TRCN0000196700:-666      120.0              h          VCAP
# ERGK013_VCAP_120H:TRCN0000039901:-666      120.0              h          VCAP
# ERGK002_VCAP_120H:N01                      120.0              h          VCAP
#
#                                           pert_mfc_id  ...  cell_iname  \
# sig_id                                                 ...
# TAK003_PC3_96H:TRCN0000245327:-666     TRCN0000245327  ...         PC3
# TAK001_HEKTE_96H:TRCN0000298904:-666   TRCN0000298904  ...       HEKTE
# TAK003_HEKTE_96H:TRCN0000059068:-666   TRCN0000059068  ...       HEKTE
# TAK001_SW480_96H:J10                   TRCN0000002173  ...       SW480
# EKW001_PC3_120H:TRCN0000021242:2       TRCN0000021242  ...         PC3
# ...                                               ...  ...         ...
# ERGK010_VCAP_120H:TRCN0000002000:-666  TRCN0000002000  ...        VCAP
# ERGK002_VCAP_120H:E03                  TRCN0000000757  ...        VCAP
# ERGK013_VCAP_120H:TRCN0000196700:-666  TRCN0000196700  ...        VCAP
# ERGK013_VCAP_120H:TRCN0000039901:-666  TRCN0000039901  ...        VCAP
# ERGK002_VCAP_120H:N01                  TRCN0000001959  ...        VCAP
#
#                                        det_wells  \
# sig_id
# TAK003_PC3_96H:TRCN0000245327:-666       M11|M12
# TAK001_HEKTE_96H:TRCN0000298904:-666         J22
# TAK003_HEKTE_96H:TRCN0000059068:-666     E07|E08
# TAK001_SW480_96H:J10                         J10
# EKW001_PC3_120H:TRCN0000021242:2             L23
# ...                                          ...
# ERGK010_VCAP_120H:TRCN0000002000:-666        P11
# ERGK002_VCAP_120H:E03                        E03
# ERGK013_VCAP_120H:TRCN0000196700:-666        J18
# ERGK013_VCAP_120H:TRCN0000039901:-666        C24
# ERGK002_VCAP_120H:N01                        N01
#
#                                                                               det_plates  \
# sig_id
# TAK003_PC3_96H:TRCN0000245327:-666     TAK003_PC3_96H_X1_B7_DUO52HI53LO|TAK003_PC3_96...
# TAK001_HEKTE_96H:TRCN0000298904:-666   TAK001_HEKTE_96H_X1_B7_DUO52HI53LO|TAK001_HEKT...
# TAK003_HEKTE_96H:TRCN0000059068:-666   TAK003_HEKTE_96H_X1_B7_DUO52HI53LO|TAK003_HEKT...
# TAK001_SW480_96H:J10                   TAK001_SW480_96H_X1_B6_DUO52HI53LO|TAK001_SW48...
# EKW001_PC3_120H:TRCN0000021242:2       EKW001_PC3_120H_X1_F1B3_DUO52HI53LO|EKW001_PC3...
# ...                                                                                  ...
# ERGK010_VCAP_120H:TRCN0000002000:-666  ERGK010_VCAP_120H_X1_B2_DUO52HI53LO|ERGK010_VC...
# ERGK002_VCAP_120H:E03                  ERGK002_VCAP_120H_X1_B2_DUO52HI53LO|ERGK002_VC...
# ERGK013_VCAP_120H:TRCN0000196700:-666  ERGK013_VCAP_120H_X1_B3_DUO52HI53LO|ERGK013_VC...
# ERGK013_VCAP_120H:TRCN0000039901:-666  ERGK013_VCAP_120H_X1_B3_DUO52HI53LO|ERGK013_VC...
# ERGK002_VCAP_120H:N01                  ERGK002_VCAP_120H_X1_B2_DUO52HI53LO|ERGK002_VC...
#
#                                                                               distil_ids  \
# sig_id
# TAK003_PC3_96H:TRCN0000245327:-666     TAK003_PC3_96H_X1_B7_DUO52HI53LO:M11|TAK003_PC...
# TAK001_HEKTE_96H:TRCN0000298904:-666   TAK001_HEKTE_96H_X1_B7_DUO52HI53LO:J22|TAK001_...
# TAK003_HEKTE_96H:TRCN0000059068:-666   TAK003_HEKTE_96H_X1_B7_DUO52HI53LO:E07|TAK003_...
# TAK001_SW480_96H:J10                   TAK001_SW480_96H_X1_B6_DUO52HI53LO:J10|TAK001_...
# EKW001_PC3_120H:TRCN0000021242:2       EKW001_PC3_120H_X1_F1B3_DUO52HI53LO:L23|EKW001...
# ...                                                                                  ...
# ERGK010_VCAP_120H:TRCN0000002000:-666  ERGK010_VCAP_120H_X1_B2_DUO52HI53LO:P11|ERGK01...
# ERGK002_VCAP_120H:E03                  ERGK002_VCAP_120H_X1_B2_DUO52HI53LO:E03|ERGK00...
# ERGK013_VCAP_120H:TRCN0000196700:-666  ERGK013_VCAP_120H_X1_B3_DUO52HI53LO:J18|ERGK01...
# ERGK013_VCAP_120H:TRCN0000039901:-666  ERGK013_VCAP_120H_X1_B3_DUO52HI53LO:C24|ERGK01...
# ERGK002_VCAP_120H:N01                  ERGK002_VCAP_120H_X1_B2_DUO52HI53LO:N01|ERGK00...
#
#                                        build_name project_code  \
# sig_id
# TAK003_PC3_96H:TRCN0000245327:-666            NaN          TAK
# TAK001_HEKTE_96H:TRCN0000298904:-666          NaN          TAK
# TAK003_HEKTE_96H:TRCN0000059068:-666          NaN          TAK
# TAK001_SW480_96H:J10                          NaN          TAK
# EKW001_PC3_120H:TRCN0000021242:2              NaN          EKW
# ...                                           ...          ...
# ERGK010_VCAP_120H:TRCN0000002000:-666         NaN         ERGK
# ERGK002_VCAP_120H:E03                         NaN         ERGK
# ERGK013_VCAP_120H:TRCN0000196700:-666         NaN         ERGK
# ERGK013_VCAP_120H:TRCN0000039901:-666         NaN         ERGK
# ERGK002_VCAP_120H:N01                         NaN         ERGK
#
#                                             cmap_name  is_exemplar_sig  \
# sig_id
# TAK003_PC3_96H:TRCN0000245327:-666             POU2F2                1
# TAK001_HEKTE_96H:TRCN0000298904:-666         EIF4EBP1                1
# TAK003_HEKTE_96H:TRCN0000059068:-666          ERBB2IP                1
# TAK001_SW480_96H:J10                             STK3                1
# EKW001_PC3_120H:TRCN0000021242:2                MECP2                0
# ...                                               ...              ...
# ERGK010_VCAP_120H:TRCN0000002000:-666          PDGFRB                0
# ERGK002_VCAP_120H:E03                            CLK1                0
# ERGK013_VCAP_120H:TRCN0000196700:-666              GK                1
# ERGK013_VCAP_120H:TRCN0000039901:-666            ABL1                0
# ERGK002_VCAP_120H:N01                  TRCN0000001959                0
#
#                                        is_ncs_sig  is_null_sig
# sig_id
# TAK003_PC3_96H:TRCN0000245327:-666            1.0          0.0
# TAK001_HEKTE_96H:TRCN0000298904:-666          1.0          0.0
# TAK003_HEKTE_96H:TRCN0000059068:-666          1.0          0.0
# TAK001_SW480_96H:J10                          1.0          0.0
# EKW001_PC3_120H:TRCN0000021242:2              1.0          0.0
# ...                                           ...          ...
# ERGK010_VCAP_120H:TRCN0000002000:-666         1.0          0.0
# ERGK002_VCAP_120H:E03                         1.0          0.0
# ERGK013_VCAP_120H:TRCN0000196700:-666         1.0          0.0
# ERGK013_VCAP_120H:TRCN0000039901:-666         1.0          0.0
# ERGK002_VCAP_120H:N01                         1.0          0.0
#
# [16853 rows x 36 columns]

# %%
# add the shRNA experiments number
for g in ec_table.index:
    if g in sig_info_shRNA['cmap_name'].unique():
        ec_table.at[g, 'total_shRNA_expr'] = sig_info_shRNA[sig_info_shRNA['cmap_name'] == g].shape[0]
    else:
        ec_table.at[g, 'total_shRNA_expr'] = 'Not available'

# %%
ec_table
# Out:
#          EC_profile total_shRNA_expr
# TYRO3         NR-EC                6
# TMCC2         NR-EC    Not available
# NDRG3         NR-EC    Not available
# ATP9A         NR-EC    Not available
# FGD1          NR-EC    Not available
# ...             ...              ...
# TNFRSF1B       R-EC    Not available
# CFLAR          R-EC               31
# NCF4           R-EC    Not available
# NSMCE4A        R-EC    Not available
# BLNK           R-EC                2
#
# [1329 rows x 2 columns]

# %%
sig_info_cp = sig_info[sig_info['pert_type'] == 'trt_cp']
sig_info_cp['target'] = 'Not available'
# Out:
# <ipython-input-37-7de2bdf146e0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sig_info_cp['target'] = 'Not available'

# %%
for s in sig_info_cp.index:
    tmp_d = sig_info_cp.loc[s, 'cmap_name']
    if tmp_d in compound_info.index:
        sig_info_cp.at[s, 'target'] = compound_info.loc[tmp_d, 'target']

# %%
# add the pharmacological inhibition experiments number
for g in ec_table.index:
    if g in sig_info_cp['target'].unique():
        ec_table.at[g, 'total_pharmacological_expr'] = sig_info_cp[sig_info_cp['target'] == g].shape[0]
    else:
        ec_table.at[g, 'total_pharmacological_expr'] = 'Not available'

# %%
ec_table
# Out:
#          EC_profile total_shRNA_expr total_pharmacological_expr
# TYRO3         NR-EC                6              Not available
# TMCC2         NR-EC    Not available              Not available
# NDRG3         NR-EC    Not available              Not available
# ATP9A         NR-EC    Not available              Not available
# FGD1          NR-EC    Not available              Not available
# ...             ...              ...                        ...
# TNFRSF1B       R-EC    Not available              Not available
# CFLAR          R-EC               31              Not available
# NCF4           R-EC    Not available              Not available
# NSMCE4A        R-EC    Not available              Not available
# BLNK           R-EC                2              Not available
#
# [1329 rows x 3 columns]

# %%
ec_table['shRNA_cell_lines'] = 'Not available'
ec_table['compound_cell_lines'] = 'Not available'

# %%
# add the cell line counts
for g in ec_table.index:
    if ec_table.loc[g, 'total_shRNA_expr'] != 'Not available':
        tmp_g_sig = sig_info_shRNA[sig_info_shRNA['cmap_name'] == g]
        tmp_g_sig_count = df(tmp_g_sig['cell_mfc_name'].value_counts())
        ec_table.at[g, 'shRNA_cell_lines'] = list(tmp_g_sig_count.index)
    if ec_table.loc[g, 'total_pharmacological_expr'] != 'Not available':
        tmp_g_sig = sig_info_cp[sig_info_cp['target'] == g]
        tmp_g_sig_count = df(tmp_g_sig['cell_mfc_name'].value_counts())
        ec_table.at[g, 'compound_cell_lines'] = list(tmp_g_sig_count.index)

# %%
ec_table
# Out:
#          EC_profile total_shRNA_expr total_pharmacological_expr  \
# TYRO3         NR-EC                6              Not available
# TMCC2         NR-EC    Not available              Not available
# NDRG3         NR-EC    Not available              Not available
# ATP9A         NR-EC    Not available              Not available
# FGD1          NR-EC    Not available              Not available
# ...             ...              ...                        ...
# TNFRSF1B       R-EC    Not available              Not available
# CFLAR          R-EC               31              Not available
# NCF4           R-EC    Not available              Not available
# NSMCE4A        R-EC    Not available              Not available
# BLNK           R-EC                2              Not available
#
#                                            shRNA_cell_lines  \
# TYRO3                               [MCF7, VCAP, PC3, A375]
# TMCC2                                         Not available
# NDRG3                                         Not available
# ATP9A                                         Not available
# FGD1                                          Not available
# ...                                                     ...
# TNFRSF1B                                      Not available
# CFLAR     [A375, A549, VCAP, HT29, HCC515, HEPG2, NPC, P...
# NCF4                                          Not available
# NSMCE4A                                       Not available
# BLNK                                          [HEKTE, A375]
#
#          compound_cell_lines
# TYRO3          Not available
# TMCC2          Not available
# NDRG3          Not available
# ATP9A          Not available
# FGD1           Not available
# ...                      ...
# TNFRSF1B       Not available
# CFLAR          Not available
# NCF4           Not available
# NSMCE4A        Not available
# BLNK           Not available
#
# [1329 rows x 5 columns]

# %%
ec_table.to_csv(poseidon_home + 'EC_signatures/all_NREC_REC_gene_info.csv', sep=',')

# %%
# only show both shRNA and compound available
bitarget_table = ec_table[ec_table['total_pharmacological_expr'] != 'Not available']
bitarget_table = bitarget_table[bitarget_table['total_shRNA_expr'] != 'Not available']
bitarget_table.shape
# Out:
# (42, 5)

# %%
bitarget_table
# Out:
#          EC_profile total_shRNA_expr total_pharmacological_expr  \
# ATP1A1        NR-EC                2                        513
# APP           NR-EC                1                          3
# CSNK2A1       NR-EC                1                         55
# CDK2          NR-EC                6                       1528
# PI4KB         NR-EC                2                          6
# IGF1R         NR-EC                7                        142
# PTK2          NR-EC               21                         14
# AURKA         NR-EC               32                        156
# FASN          NR-EC                2                         19
# TYMS          NR-EC                3                         63
# RRM1          NR-EC                9                        189
# PLK1          NR-EC                7                        761
# HSP90AA1      NR-EC               11                       1837
# CSNK1E        NR-EC               18                          4
# MET           NR-EC               11                        102
# HMGCR         NR-EC                6                        146
# FDPS          NR-EC                3                          1
# CDK5          NR-EC                2                         52
# ACLY          NR-EC                4                         25
# DHFR          NR-EC                4                        118
# BIRC5         NR-EC               12                        222
# CDK4          NR-EC                6                        202
# APEX1         NR-EC                1                         13
# PAK4          NR-EC                4                        158
# PARP1         NR-EC                3                         86
# SMAD3         NR-EC               13                          1
# SMO           NR-EC                3                         52
# CTNNB1        NR-EC               11                         16
# AKT3          NR-EC               12                         85
# TOP2A         NR-EC                3                       2297
# PRKDC         NR-EC               12                         30
# HDAC2         NR-EC               13                         35
# FKBP1A        NR-EC                3                        439
# PPIA          NR-EC               21                         50
# CDK7          NR-EC                5                          6
# EPHA2         NR-EC                8                        325
# DPYD           R-EC                3                         23
# RPS6KA1        R-EC               17                         16
# LCK            R-EC               15                          6
# FBP1           R-EC                5                          1
# DPP4           R-EC                1                         43
# JAK3           R-EC                1                         30
#
#                                            shRNA_cell_lines  \
# ATP1A1                                        [HA1E, HEPG2]
# APP                                                  [A549]
# CSNK2A1                                              [A375]
# CDK2                        [MCF7, HT29, U2OS, A375, SW480]
# PI4KB                                                [VCAP]
# IGF1R                        [PC3, VCAP, HT29, HEPG2, A549]
# PTK2      [HA1E, MCF7, PC3, VCAP, HT29, A549, A375, HEK2...
# AURKA     [HEPG2, A549, A375, MCF7, HA1E, NPC, HEK293T, ...
# FASN                                           [HT29, A549]
# TYMS                                           [A375, A549]
# RRM1                               [HT29, A375, MCF7, A549]
# PLK1                              [PC3, A375, VCAP, HCC515]
# HSP90AA1              [MCF7, PC3, HA1E, SW480, HEKTE, HT29]
# CSNK1E    [MCF7, PC3, A375, HEKTE, A549, HT29, HA1E, SW4...
# MET                    [HA1E, A549, HT29, PC3, HEPG2, VCAP]
# HMGCR                              [A549, A375, HT29, MCF7]
# FDPS                                    [A549, HT29, HEPG2]
# CDK5                                            [HA1E, PC3]
# ACLY                                    [A375, HEPG2, MCF7]
# DHFR                                     [HA1E, A549, A375]
# BIRC5      [A549, HT29, PC3, HA1E, MCF7, HEKTE, A375, VCAP]
# CDK4                              [VCAP, HEKTE, A549, A375]
# APEX1                                                [MCF7]
# PAK4                              [HT29, HEPG2, A549, A375]
# PARP1                                         [HT29, HEPG2]
# SMAD3     [PC3, A375, HT29, HEPG2, HA1E, MCF7, SW480, HE...
# SMO                                           [VCAP, HEKTE]
# CTNNB1    [DLD1, A549, HT29, SHSY5Y, HA1E, HEKTE, HEPG2,...
# AKT3              [PC3, MCF7, A375, HT29, HA1E, A549, VCAP]
# TOP2A                                           [NPC, VCAP]
# PRKDC                  [PC3, VCAP, A375, MCF7, HEPG2, A549]
# HDAC2     [PC3, ASC, A549, VCAP, HA1E, HEK293T, HCC515, ...
# FKBP1A                                         [A375, VCAP]
# PPIA      [HA1E, A549, PC3, HT29, HCC515, HEPG2, VCAP, M...
# CDK7                                [PC3, VCAP, A549, MCF7]
# EPHA2                         [MCF7, A549, VCAP, NPC, A375]
# DPYD                                           [A549, HA1E]
# RPS6KA1   [A375, HA1E, PC3, VCAP, HT29, MCF7, HCC515, HE...
# LCK               [HT29, PC3, HA1E, MCF7, A549, A375, VCAP]
# FBP1                                     [A375, A549, VCAP]
# DPP4                                                 [VCAP]
# JAK3                                                 [VCAP]
#
#                                         compound_cell_lines
# ATP1A1    [MCF7, A549, PC3, HA1E, A375, U2OS, HT29, HCC5...
# APP                                       [PC3, HA1E, MCF7]
# CSNK2A1   [A375, HA1E, PC3, MCF7, HELA, A549, HEPG2, MCF...
# CDK2      [MCF7, A549, PC3, A375, HT29, MDAMB231, MCF10A...
# PI4KB                  [SKBR3, HA1E, BT20, PC3, A375, MCF7]
# IGF1R     [HT29, A375, MCF7, HCC515, MCF10A.WT, A549, HE...
# PTK2              [HT29, HA1E, MCF7, PC3, A375, HELA, YAPC]
# AURKA     [MCF7, A375, PC3, HA1E, A549, HEPG2, HCC515, N...
# FASN      [MCF7, HA1E, PC3, A375, HT29, RKO, A673, SKM1,...
# TYMS      [MCF7, A549, PC3, A375, MCF10A, YAPC, HT29, U2...
# RRM1      [A549, PC3, MCF7, A375, HT29, YAPC, MCF10A, MD...
# PLK1      [MCF7, PC3, A375, HT29, HA1E, HELA, A549, JURK...
# HSP90AA1  [MCF7, A549, PC3, A375, HEPG2, HT29, HA1E, VCA...
# CSNK1E                              [A549, PC3, HA1E, MCF7]
# MET       [A375, PC3, MCF7, HA1E, HT29, HELA, NPC.CAS9, ...
# HMGCR     [PC3, A375, HA1E, MCF7, A549, MDAMB231, HCC515...
# FDPS                                                 [HUH7]
# CDK5      [A375, PC3, HEPG2, HA1E, A549, HT29, VCAP, HUH...
# ACLY      [MCF7, HT29, HCC515, PC3, VCAP, LOVO, A673, A5...
# DHFR      [MCF7, PC3, JURKAT, THP1, MCF10A, HT29, A375, ...
# BIRC5     [PC3, MCF7, HT29, A375, A549, HA1E, U2OS, HELA...
# CDK4      [MCF7, A375, A549, HT29, MCF10A.WT, PC3, MDAMB...
# APEX1            [MCF7, HEPG2, A549, PC3, A375, HA1E, VCAP]
# PAK4      [PC3, A375, MCF10A, MCF7, HELA, HEK293, HT29, ...
# PARP1     [MCF7, PC3, HA1E, HELA, A549, U2OS, HT29, VCAP...
# SMAD3                                                [HT29]
# SMO       [HCT116.WT, MCF7, MCF10A.KRAS.HG, A549, MCF10A...
# CTNNB1    [MCF10A.WT, MCF10A.KRAS.HG, MCF10A.PIK3CA.HH, ...
# AKT3      [MCF7, PC3, HEPG2, HA1E, HT29, JURKAT, HEK293,...
# TOP2A     [MCF7, A549, A375, PC3, HEPG2, HA1E, HT29, U2O...
# PRKDC     [PC3, MCF7, HCC515, A375, HA1E, MDAMB231, HT29...
# HDAC2     [A375, HAP1.SRC, HAP1, HAP1.MAPK8, HAP1.CDK4, ...
# FKBP1A    [PC3, A549, A375, VCAP, HCC515, HT29, U2OS, HE...
# PPIA      [A549, MCF7, PC3, HEPG2, HT29, HA1E, A375, MCF...
# CDK7             [HUVEC, JURKAT, SKL.C, MNEU.E, A375, CD34]
# EPHA2     [A375, MDAMB231, HA1E, SKL, MCF10A, YAPC, PC3,...
# DPYD      [MCF7, A549, PC3, HPTEC, JURKAT, U2OS, HUH7, H...
# RPS6KA1   [THP1, K562, OCILY19, TMD8, U2OS, NALM6, KMS34...
# LCK                  [HT29, HEPG2, HCC515, PC3, HA1E, MCF7]
# FBP1                                                [HEPG2]
# DPP4      [HA1E, PC3, A375, HELA, MDAMB231, YAPC, MCF7, ...
# JAK3      [SKL.C, MCF10A, HCC515, SKL, PC3, HUVEC, CD34,...

# %%
bitarget_table.to_csv(poseidon_home + 'EC_signatures/sh_cp_available_NREC_REC_gene_info.csv', sep=',')

# %% [markdown]
# # Correlation with TCGA

# %%
# corr between EC genes
skcm_corr = pd.read_csv(poseidon_home + 'results/corr_EC_TCGA/pearson_corr_SKCM.csv', header=0, index_col=0, sep=',')

# %%
skcm_corr
# Out:
#             AAAS      AACS      AAR2     ABCA1     ABCB6     ABCF1     ABCF2  \
# 0
# AAAS    1.000000  0.236276  0.424416 -0.285606  0.438673  0.259273  0.352424
# AACS    0.236276  1.000000  0.131968 -0.057989  0.214873 -0.045781  0.297612
# AAR2    0.424416  0.131968  1.000000 -0.248447  0.405184  0.459602  0.334302
# ABCA1  -0.285606 -0.057989 -0.248447  1.000000 -0.312898 -0.250074 -0.176501
# ABCB6   0.438673  0.214873  0.405184 -0.312898  1.000000  0.236599  0.270337
# ...          ...       ...       ...       ...       ...       ...       ...
# ZNF609  0.101263  0.081436  0.275127 -0.117184  0.050515  0.256953  0.130837
# ZNF623 -0.152364 -0.260586  0.058957  0.025425  0.042107  0.157950 -0.111050
# ZNF74   0.280503  0.052418  0.442682 -0.414653  0.349357  0.430215  0.290382
# ZNF768  0.447919  0.180839  0.510817 -0.374302  0.444040  0.421762  0.339374
# ZWILCH -0.158950 -0.009862 -0.397273 -0.003304 -0.183111 -0.143058 -0.125365
#
#            ABTB2     ACAA1     ACACA  ...    ZNF318    ZNF330    ZNF343  \
# 0                                     ...
# AAAS   -0.035436  0.279098 -0.049569  ... -0.258990  0.068324  0.048076
# AACS   -0.088229  0.192619  0.155996  ... -0.315955  0.037399 -0.111298
# AAR2    0.194938  0.217625  0.138566  ... -0.015936  0.198518  0.229531
# ABCA1  -0.163644 -0.040916 -0.244928  ... -0.076397 -0.183227 -0.249146
# ABCB6   0.143525  0.192916  0.136091  ... -0.136184  0.131749  0.125944
# ...          ...       ...       ...  ...       ...       ...       ...
# ZNF609  0.019254 -0.098940  0.199880  ...  0.166489 -0.005131  0.135049
# ZNF623  0.168558 -0.337588  0.238422  ...  0.330183  0.227656  0.308882
# ZNF74   0.181186 -0.066233  0.309652  ...  0.141776  0.274512  0.337962
# ZNF768  0.103181  0.208406  0.042280  ... -0.143280  0.196521  0.144523
# ZWILCH -0.182896 -0.326643  0.101137  ...  0.066067 -0.128265  0.145780
#
#           ZNF473    ZNF532    ZNF609    ZNF623     ZNF74    ZNF768    ZWILCH
# 0
# AAAS   -0.043022 -0.063314  0.101263 -0.152364  0.280503  0.447919 -0.158950
# AACS   -0.187129 -0.055083  0.081436 -0.260586  0.052418  0.180839 -0.009862
# AAR2    0.118219  0.088690  0.275127  0.058957  0.442682  0.510817 -0.397273
# ABCA1  -0.247034  0.151754 -0.117184  0.025425 -0.414653 -0.374302 -0.003304
# ABCB6   0.056349 -0.039160  0.050515  0.042107  0.349357  0.444040 -0.183111
# ...          ...       ...       ...       ...       ...       ...       ...
# ZNF609  0.068845  0.101667  1.000000  0.045047  0.199144  0.150337 -0.015441
# ZNF623  0.368400  0.227200  0.045047  1.000000  0.233250  0.035923  0.054773
# ZNF74   0.419868  0.060441  0.199144  0.233250  1.000000  0.502109 -0.044020
# ZNF768  0.144929 -0.106521  0.150337  0.035923  0.502109  1.000000 -0.279203
# ZWILCH  0.281062  0.139389 -0.015441  0.054773 -0.044020 -0.279203  1.000000
#
# [1320 rows x 1320 columns]
